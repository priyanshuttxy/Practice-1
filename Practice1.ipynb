# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import warnings as wn
wn.filterwarnings("ignore")

# %%
data=pd.read_csv("C:/Users/ASUS/Desktop/Salary_Data.csv")

# %%
df=pd.DataFrame(data)
df
df.dropna(inplace=True)
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
x=df[["Years of Experience"]]
y=df["Salary"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/5, random_state=0)
x_train
# Out:
#       Years of Experience
# 2895                 11.0
# 328                  10.0
# 2029                  4.0
# 5127                  8.0
# 5721                  9.0
# ...                   ...
# 4935                 10.0
# 3268                  9.0
# 1655                 18.0
# 2610                 17.0
# 2735                  8.0
#
# [5358 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prd=lr.predict(x_test)
prd1=lr.predict(x_train)
prd, prd1
# Out:
# (array([178309.11635368, 121956.77756695,  72648.48112855, ...,
#          93780.60817358, 241705.49748876, 129000.81991529]),
#  array([136044.86226363, 129000.81991529,  86736.56582524, ...,
#         185353.15870202, 178309.11635368, 114912.73521861]))

# %%
plt.scatter(x_test[0:20],y_test[0:20])
plt.plot(x_test[0:20],prd[0:20],color="Red")

# %%
sc=lr.score(x_test,y_test)
sc
# Out:
# 0.6645301353853268

# %%
df=df[["Age","Gender","Years of Experience","Salary"]]
x1=df[["Age","Gender","Years of Experience"]]
y1=df[["Salary"]]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()
x1["Gender"]=l.fit_transform(x1["Gender"])
x1
# Out:
#        Age  Gender  Years of Experience
# 0     32.0       1                  5.0
# 1     28.0       0                  3.0
# 2     45.0       1                 15.0
# 3     36.0       0                  7.0
# 4     52.0       1                 20.0
# ...    ...     ...                  ...
# 6699  49.0       0                 20.0
# 6700  32.0       1                  3.0
# 6701  30.0       0                  4.0
# 6702  46.0       1                 14.0
# 6703  26.0       0                  1.0
#
# [6698 rows x 3 columns]

# %%
xtest,xtrain,ytest,ytrain=train_test_split(x1,y1,test_size=0.3,random_state=None)
xtest.head()
# Out:
#        Age  Gender  Years of Experience
# 1355  25.0       1                  1.0
# 1608  27.0       0                  2.0
# 2561  50.0       0                 25.0
# 6177  27.0       1                  3.0
# 1789  30.0       1                  5.0

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
pr=lr.predict([[21,1,4]])
xtest,pr
# Out:
# (       Age  Gender  Years of Experience
#  1355  25.0       1                  1.0
#  1608  27.0       0                  2.0
#  2561  50.0       0                 25.0
#  6177  27.0       1                  3.0
#  1789  30.0       1                  5.0
#  ...    ...     ...                  ...
#  1904  30.0       1                  5.0
#  545   33.0       0                 11.0
#  2128  42.0       1                 13.0
#  2912  26.0       1                  3.0
#  2025  30.0       1                  5.0
#
#  [4688 rows x 3 columns],
#  array([[109950.30060536]]))

# %%
s=lr.score(xtest,ytest)
s
# Out:
# 0.6559527027676271
